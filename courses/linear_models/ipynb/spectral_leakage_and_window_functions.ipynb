# %%
import numpy as np
import matplotlib.pyplot as plt

num_samples = 600
sample_rate = 800

def plot_sin_func():
    x = np.linspace(0.0, num_samples / sample_rate, num_samples, endpoint=False)
    sinus = np.sin(10 * 2 * np.pi * x) + 10 * np.sin(20 * 2 * np.pi * x) + 3 * np.sin(50 * 2 * np.pi * x) + 7 * np.sin(100 * 2 * np.pi * x) # 10 Гц, 20 Гц, 50 Гц, 100 Гц
    plt.plot(x, sinus)
    return sinus

# %%
signal_ = plot_sin_func()

# %%
from numpy.fft import fft, fftfreq

yf = fft(signal_) # комплексный спектр
xf = fftfreq(num_samples, 1 / sample_rate) # частоты, аргументы - число отсчетов и период дискретизации (в секундах)
yf_mod = np.abs(yf) # действительная часть комплексного спетктра
yf_ang = np.angle(yf) # фазовая часть комплексного спектра

# %%
plt.plot(xf, yf_mod)
plt.axis([-150, 150, -0, 3100])
plt.xlabel("Frequency, Hz")
plt.ylabel("Amplitude")
plt.grid()
plt.show()

# %%
from scipy import signal

# %%
rect_w = signal.get_window("boxcar", num_samples)
windowed_signal_rect = signal_ * rect_w

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

ax1.plot(xf, np.abs(rect_w))
ax1.set_title('Boxcar / rectangular / Dirichlet window')
ax1.set_xlabel("Sample")
ax1.set_ylabel("Amplitude")
ax1.grid(True)

ax2.plot(x, windowed_signal_rect)
ax2.grid(True)

plt.show()

# %%
yf_windowed = fft(windowed_signal_rect)
yf_not_windowed = fft(signal_)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

ax1.plot(xf, np.abs(yf_windowed))
ax1.set_title('С применением оконной функции, \n прямоугольное окно')
ax1.set_xlabel("Frequency, Hz")
ax1.set_ylabel("Amplitude")
ax1.set_xlim(0, 200)
ax1.grid(True)

ax2.plot(xf, np.abs(yf_not_windowed))
ax2.set_title('Без применения оконной функции')
ax2.set_xlabel("Frequency, Hz")
ax2.set_ylabel("Amplitude")
ax2.set_xlim(0, 200)
ax2.grid(True)

plt.show()

# %%
triang_w = signal.get_window("triang", num_samples)
windowed_signal_triang = signal_ * triang_w

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

ax1.plot(triang_w)
ax1.set_title('Triangular window')
ax1.set_xlabel("Sample")
ax1.set_ylabel("Amplitude")
ax1.grid(True)

ax2.plot(x, windowed_signal_triang)
ax2.grid(True)

plt.show()

# %%
yf_windowed = fft(windowed_signal_triang) / 0.5   # делим на норму окна
yf_not_windowed = fft(signal_)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

ax1.plot(xf, np.abs(yf_windowed))
ax1.set_title('С применением оконной функции, \n треугольное окно')
ax1.set_xlabel("Frequency, Hz")
ax1.set_ylabel("Amplitude")
ax1.set_xlim(0, 200)
ax1.grid(True)

ax2.plot(xf, np.abs(yf_not_windowed))
ax2.set_title('Без применения оконной функции')
ax2.set_xlabel("Frequency, Hz")
ax2.set_ylabel("Amplitude")
ax2.set_xlim(0, 200)
ax2.grid(True)

plt.show()

# %%
hann_w = signal.get_window("hann", num_samples)
windowed_signal_hann = signal_ * hann_w

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

ax1.plot(hann_w)
ax1.set_title('Hann window')
ax1.set_xlabel("Sample")
ax1.set_ylabel("Amplitude")
ax1.grid(True)

ax2.plot(x, windowed_signal_hann)
ax2.grid(True)

plt.show()

# %%
yf_windowed = fft(windowed_signal_hann) / 0.5   # делим на норму окна
yf_not_windowed = fft(signal_)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

ax1.plot(xf, np.abs(yf_windowed))
ax1.set_title('С применением оконной функции, \n окно Ханна')
ax1.set_xlabel("Frequency, Hz")
ax1.set_ylabel("Amplitude")
ax1.set_xlim(0, 200)
ax1.grid(True)

ax2.plot(xf, np.abs(yf_not_windowed))
ax2.set_title('Без применения оконной функции')
ax2.set_xlabel("Frequency, Hz")
ax2.set_ylabel("Amplitude")
ax2.set_xlim(0, 200)
ax2.grid(True)

plt.show()

# %%
hamming_w = signal.get_window("hamming", num_samples)
windowed_signal_hamming = signal_ * hamming_w

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

ax1.plot(hamming_w)
ax1.set_title('Hamming window')
ax1.set_xlabel("Sample")
ax1.set_ylabel("Amplitude")
ax1.grid(True)

ax2.plot(x, windowed_signal_hamming)
ax2.grid(True)

plt.show()

# %%
yf_windowed = fft(windowed_signal_hamming) / 0.54   # делим на норму окна
yf_not_windowed = fft(signal_)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

ax1.plot(xf, np.abs(yf_windowed))
ax1.set_title('С применением оконной функции, \n окно Хэмминга')
ax1.set_xlabel("Frequency, Hz")
ax1.set_ylabel("Amplitude")
ax1.set_xlim(0, 200)
ax1.grid(True)

ax2.plot(xf, np.abs(yf_not_windowed))
ax2.set_title('Без применения оконной функции')
ax2.set_xlabel("Frequency, Hz")
ax2.set_ylabel("Amplitude")
ax2.set_xlim(0, 200)
ax2.grid(True)

plt.show()

# %%
blackman_w = signal.get_window("blackman", num_samples)
windowed_signal_blackman = signal_ * blackman_w

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

ax1.plot(blackman_w)
ax1.set_title('Blackman window')
ax1.set_xlabel("Sample")
ax1.set_ylabel("Amplitude")
ax1.grid(True)

ax2.plot(x, windowed_signal_blackman)
ax2.grid(True)

plt.show()

# %%
yf_windowed = fft(windowed_signal_blackman) / 0.42   # делим на норму окна
yf_not_windowed = fft(signal_)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

ax1.plot(xf, np.abs(yf_windowed))
ax1.set_title('С применением оконной функции, \n окно Блэкмана')
ax1.set_xlabel("Frequency, Hz")
ax1.set_ylabel("Amplitude")
ax1.set_xlim(0, 200)
ax1.grid(True)

ax2.plot(xf, np.abs(yf_not_windowed))
ax2.set_title('Без применения оконной функции')
ax2.set_xlabel("Frequency, Hz")
ax2.set_ylabel("Amplitude")
ax2.set_xlim(0, 200)
ax2.grid(True)

plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

ax1.plot(xf, np.log(np.abs(yf_windowed)))
ax1.set_title('С применением оконной функции, \n окно Блэкмана')
ax1.set_xlabel("Frequency, Hz")
ax1.set_ylabel("Amplitude (log)")
ax1.set_xlim(0, 150)
ax1.set_ylim(-8, 8)
ax1.grid(True)

ax2.plot(xf, np.log(np.abs(yf_not_windowed)))
ax2.set_title('Без применения оконной функции')
ax2.set_xlabel("Frequency, Hz")
ax2.set_ylabel("Amplitude (log)")
ax2.set_xlim(0, 150)
ax2.set_ylim(-8, 8)
ax2.grid(True)

plt.show()
