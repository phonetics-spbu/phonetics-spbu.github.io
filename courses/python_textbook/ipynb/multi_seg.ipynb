# %%
# !wget -q https://phonetics-spbu.github.io/courses/python_textbook/files/segtools.py
# !wget -q https://phonetics-spbu.github.io/courses/python_textbook/files/cta0001.seg_B1
# !wget -q https://phonetics-spbu.github.io/courses/python_textbook/files/cta0001.seg_Y1

# %% [markdown]
# <div class="note">

# %% [markdown]
# ### Файловые системы

# %% [markdown]
# Файловые системы обладают древовидной структурой: файлы могут бьть помещены в директории (папки), которые могут быть вложенными. Пример файлового дерева приведён ниже.

# %% [markdown]
# Имя файла, то есть его уникальный (для данной папки) идентификатор &mdash; это строка. В любой системе существуют ограничения на имена файлов, в частности, на символы, которые могут в них встречаться. Рекомендуется ограничиваться символами ASCII (кроме зарезервированных) и не использовать пробелы.
#
# Часть имени файла между последней точкой и концом &mdash; его расширение. Оно указывает на тип его содержимого, но эта связь условна и существует только по договорённости.
#
# Имя файла нужно отличать от переменной, которая работает непосредственно с файлом:

# %%
with open("lol.txt", "w") as f:
    print(type(f))

# %% [markdown]
# Здесь переменная `f` указывает на специальный объект, предназначенный для работы с указанным файлом.
#
# В Windows имена папок и файлов разделяются между собой обратным слешем `\`. В Unix, Mac &mdash; прямым слешем `/`.
#
# ![image](https://phonetics-spbu.github.io/courses/python_textbook/images/paths.jpg)
#
# Обратный слеш в строках Python используется для *escape*-последовательностей, таких как `\n` или `\t`. Поэтому, если вы работаете на Windows, нужно быть внимательным. Прописывать пути можно любым из перечисленных ниже способов:
#
# 1. Используя &laquo;сырые&raquo; строки (*r-strings*), в которых все служебные последовательности игнорируются.

# %%
path = r"C:\Folder_1\file1.txt"

# %% [markdown]
# 2. Используя *escape*-последовательность `\\`, обозначающую обратный слеш.

# %%
path = "C:\\Folder_1\\file1.txt"

# %% [markdown]
# 3. Используя прямой слеш (Python автоматически подставит системный разделитель путей).

# %%
path = "C:/Folder_1/file1.txt"

# %% [markdown]
# Если вы работаете на Mac или в любой Unix-подобной системе (включая Google Colab), используйте только последний вариант.
#
# Пути бывают относительные и абсолютные. Абсолютные указывают путь от корневой папки (или от буквы диска в Windows). Относительные указывают путь от текущей папки (из которой запускается код). Переход на один уровень вверх обозначается двумя точками `..`.

# %%
path1 = "Folder_2/file_3.docx"
path2 = r"../file4.png"

# %% [markdown]
# #### Модуль `os`

# %% [markdown]
# Для работы с путями и файловыми системами существует несколько встроенных модулей. Ряд полезных функций содержится в модуле [`os`](https://docs.python.org/3/library/os.html) и во входящем в нём модуле [`os.path`](https://docs.python.org/3/library/os.path.html).

# %%
import os

# %% [markdown]
# Функция `os.path.join()` позволяет соединить несколько имён в один путь:

# %%
filepath = os.path.join("Folder_1", "file1.txt")

# %% [markdown]
# Функция `os.path.split()`, наоборот, делит путь на составляющие: путь к последнему элементу (файлу или папке) и имя самого последнего элемента.

# %%
path, file = os.path.split("C:/Folder_1/file1.txt")
print(path)
print(file)

# %% [markdown]
# В константе `os.sep` хранится системный разделитель путей:

# %%
print(os.sep)

# %% [markdown]
# В Unix-подобных системах код выше выведет слеш.
#
# Функция `os.path.splitext` позволяет отделить расширение от имени файла:

# %%
file, ext = os.path.splitext("file1.txt")
print(file)
print(ext)

# %% [markdown]
# Функция `os.path.exists()` вернёт `True`, если путь, переданный в неё, действительно существует, и `False` в противном случае.

# %%
print(os.path.exists("Folder_1"))

# %% [markdown]
# Её удобно использовать с условным оператором:

# %%
if not os.path.exists("Folder_1"):
    ...

# %% [markdown]
# Функция `os.makedirs()` позволяет создать папку по заданному пути, при этом все промежуточные папки, если их нет, будут созданы. Если конечная папка уже существует, будет вызвана ошибка.

# %%
os.makedirs("Folder_1/Folder_2")

# %% [markdown]
# Функция `os.listdir()` возвращает список всех файлов и папок внутри папки (без какого-либо порядка). Если пути, который был передан в функцию, не существует, или это не директория, будет вызвана ошибка.

# %%
print(os.listdir("C:/Folder_1"))

# %% [markdown]
# Функция `os.scandir()` аналогична `os.listdir()`, но возвращает не список, а итератор, который можно использовать в цикле.

# %%
for name in os.scandir("C:/Folder_1"):
    print(name)

# %% [markdown]
# Функция `os.walk()` позволяет совершать рекурсивный обход файлового дерева, заходя в каждую встретившуюся папку. `"."` обозначает текущую директорию. На каждом шаге она возвращает путь к обрабатываемой директории, список её поддиректорий и список её файлов.

# %%
for root, dirs, files in os.walk("."):
    print(root, dirs, files)

# %% [markdown]
# Функция `os.chdir()` позволяет сменить текущую директорию.

# %% [markdown]
# #### Модуль `glob`

# %% [markdown]
# ![image](https://phonetics-spbu.github.io/courses/python_textbook/images/i-am-glob.png)
#
# Модуль `glob` позволяет находить пути по заданной маске (по правилам Unix). Используются следующие основные символы: `?` &mdash; заместитель одного символа, `*` &mdash; заместитель произвольного количества символов (в том числе нулевого).
#
# Например, маска `"cta????.wav"` будет соответствовать всем файлам, у которых после букв *cta* идёт ровно 4 символа, а затем расширение *.wav*. Маска `"cta*.wav"` будет соответствовать всем файлам, название которых начинается с букв *cta* и заканчивается расширением *.wav* (в том числе *cta.wav*). По маске `"*.*"` найдутся файлы с любыми названиями и расширениями.
#
# В квадратных скобках `[]` можно указывать набор подходящих символов (`[abc]`) или диапазон (`[a-c]`). Если сразу после открывающей скобки поставить восклицательный знак `!`, то под маску будут подходить все символы, кроме перечисленных в скобках.
#
# Примечание: `glob` внутри себя использует `os.scandir()` и функцию `fnmatch()` из модуля `fnmatch`, которая определяет, подходит ли данное имя под заданную маску.
#
# Функция `glob.glob()` возвращает список путей, подходящих под заданную маску.

# %%
import glob

print(glob.glob("C:/Folder_1/*.*"))

# %% [markdown]
# Маска может отражать как абсолютный путь, так и относительный. Относительный путь будет отсчитываться от текущей папки или от директории, переданной в необязательном аргументе `root_dir`.
#
# Если передать аргумент `recursive=True`, то `**` будет обозначать любую последовательность директорий или файлов (в том числе пустую). Обратите внимание, что в больших файловых деревьях использование `**` может приводить к большому времени поиска. Если передать аргумент `include_hidden=True`, то в `**` будут входить и скрытые директории.

# %%
print(glob.glob("C:/**/*.*"))

# %% [markdown]
# Функция `glob.iglob()`, в отличие от `glob.glob()`, вместо списка возвращает итератор, что позволяет не хранить весь список в памяти:

# %%
for file in glob.iglob("C:/Folder_1/*.*"):
    ...

# %% [markdown]
# </div>

# %% [markdown]
# ### Работа с многоуровневой разметкой

# %% [markdown]
# В большинстве случаев разметка обладает иерархической структурой: например, если в сигнале на разных уровнях отмечены границы звуков, слов и синтагм, то каждая синтагма состоит из определённых слов, каждое из которых, в свою очередь, состоит из определённых звуков. В связи с этим полезно уметь определять, какие интервалы более низкого уровня входят в какие интервалы более высокого.
#
# Определим, из каких звуков состоит каждое слово в файле cta0001.wav. В корпусе CORPRES реальная транскрипция размещена на уровне B1, а границы слов &mdash; на уровне Y1.
#
# Используем написанную ранее функцию `read_seg()`, чтобы прочитать метки на обоих уровнях. Обратите внимание, что метки Y1 содержат кириллические буквы и были записаны в кодировке Windows-1251.

# %%
from segtools import read_seg

params, labels_upper = read_seg("cta0001.seg_Y1")
_, labels_lower = read_seg("cta0001.seg_B1")

# %% [markdown]
# Теперь наша задача заключается в том, чтобы для каждой пары жёлтых меток определить, какие синие метки в неё попадают. Удобно считать, что интервалы, заданные двумя метками, полуоткрытые: если синяя метка совпадает с началом жёлтого интервала, она будет в него входить, а если с концом &mdash; не будет.
#
# Проще всего поступить следующим образом: переберём циклом все пары жёлтых меток (пропуская те, которые соответствуют не словам, а паузам &mdash; их имена пустые). В каждой итерации цикла переберём все синие метки и оставим только те, которые попадают в текущий жёлтый интервал.

# %%
for start, end in zip(labels_upper, labels_upper[1:]):
    if not start["name"]:
        continue
    print(start["position"], end["position"], start["name"])
    for label in labels_lower:
        if start["position"] <= label["position"] < end["position"]:
            print(label["name"], end=" ")
    print("")

# %% [markdown]
# Можно заметить, что код выше неэффективен: для каждого слова мы перебираем все синие метки заново, хотя, с одной стороны, если мы внесли синюю метки в какое-то слово до этого, в этом она точно уже не появится, а с другой &mdash; если какая-то метка вышла за границы слова, то и все метки после неё тоже в слово не попадут. Поэтому внесём в код соответствующие улучшения:

# %%
idx = 0
for start, end in zip(labels_upper, labels_upper[1:]):
    if not start["name"]:
        continue
    print(start["position"], end["position"], start["name"])
    for label in labels_lower[idx:]:
        if label["position"] >= end["position"]:
            break
        idx += 1
        print(label["name"], end=" ")
    print("")

# %% [markdown]
# Теперь в переменной `idx` мы запоминаем номер последней обработанной метки и начинаем следующий цикл после неё; а если метка вышла за границы слова, остановим цикл с помощью `break`.
#
# Обратите также внимание на этот фрагмент:

# %%
if not start["name"]:
    continue

# %% [markdown]
# Такой приём называется *guard clause*. Он позволяет сэкономить отступ: если бы мы написали более интуитивно:

# %%
if start["name"]:
    print(start["position"], end["position"], start["name"])

# %% [markdown]
# то весь последующий код у нас оказался бы сдвинут на один отступ вправо, что снижает читаемость.

# %% [markdown]
# ### Практические задания

# %% [markdown]
# #### 3.1. Поиск файлов SEG заданного уровня

# %% [markdown]
# Напишите функцию, которая принимает на вход имя папки (в данном случае *cta_seg*) и уровень *seg* (в данном случае B1 или Y1), ищет там все файлы SEG соответствующего уровня и возвращает их список.

# %% [markdown]
# #### 3.2. Сбор информации из файлов SEG

# %% [markdown]
# Модифицируйте функцию так, чтобы она открывала каждый найденный файл SEG, читала оттуда названия меток (кроме пустых) и записывала их в текстовый файл &mdash; метки из каждого файла SEG на отдельной строке, разделённые пробелами. Пример результата:

# %% [markdown]
# #### 3.3. Функция для обработки двухуровневой аннотации

# %% [markdown]
# На основе кода выше напишите функцию, которая принимает на вход два имени файлов .seg и возвращает список списков следующего формата:

# %% [markdown]
# где `метка1_*` - это метки из первого файла, а `метка2_*` - метки из второго, которые лежат между соответствующими метками из первого.

# %% [markdown]
# #### 3.4. Произносительный словарь

# %% [markdown]
# Напишите программу, которая обрабатывает корпус файлов SEG и строит на его основе произносительный словарь. Результат необходимо записать в текстовый файл в алфавитном порядке. Например:

# %% [markdown]
# Помните, что у вас обязательно возникнут слова с одинаковым написанием, но разным произношением! Каждый вариант нужно записать на своей строчке, но только один раз! Абсолютно одинаковых строк в итоговом файле быть не должно:

# %% [markdown]
# Обратите внимание, что большинство файлов в архиве закодировано в кодировке Windows-1251, но некоторые &mdash; в UTF-8. Воспользуйтесь автоматическим определением кодировки.

# %% [markdown]
# #### 3.5. Определение зависимости длины слова от количества звуков

# %% [markdown]
# На основе архива *cta_seg* с помощью [`matplotlib.pyplot.scatter()`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html) постройте график, где по оси *x* будет отложено количество составляющих слово звуков (по уровню B1), а по оси *y* &mdash; длительность слова в секундах.

# %% [markdown]
# #### 3.6. Определение зависимости длительности звука от количества звуков в слове

# %% [markdown]
# На основе архива *cta_seg* с помощью [`matplotlib.pyplot.scatter()`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html) для каждого ударного гласного постройте график, где по оси *x* будет отложено количество составляющих слово звуков (по уровню B1), а по оси *y* &mdash; длительность этого гласного в миллисекундах.

# %% [markdown]
# #### 3.7. Моделирование иерархической структуры высказывания

# %% [markdown]
# Напишите функцию, которая принимает на вход списки меток звуков, слов и синтагм и возвращает список словарей, отражающих иерархическую структуру высказывания.
#
# Каждый словарь в списке &mdash; это синтагма. У него должны быть ключи:
# * `"model"`: интонационная модель;
# * `"start"`: время начала (в отсчётах);
# * `"end"`: время конца (в отсчётах);
# * `"nucleus"`: индекс слова, содержащего интонационный центр;
# * `"words"`: список слов.
#
# Каждое слово &mdash; это тоже словарь. У него должны быть ключи:
# * `"word"`: слово в орфографической записи;
# * `"start"`: время начала (в отсчётах);
# * `"end"`: время конца (в отсчётах);
# * `"is_stressed"`: является ли слово ударным (`True` или `False`);
# * `"is_nucleus"`: является ли слово интонационным центром (`True` или `False`);
# * `"is_prominent"`: несёт ли слово дополнительную интонационную выделенность (`True` или `False`);
# * `"stressed_vowel"`: индекс ударного гласного;
# * `"sounds"`: список звуков.
#
# Каждый звук &mdash; это тоже словарь. У него должны быть ключи:
# * `"sound"`: обозначение аллофона;
# * `"start"`: время начала (в отсчётах);
# * `"end"`: время конца (в отсчётах).
#
# Протестируйте функцию на разметке к файлу *cta0003.wav*. Используя модуль [`json`](https://docs.python.org/3/library/json.html), запишите список словарей в файл JSON.

# %%
import json

data = [
    {"a": 1, "b": 2},
    {"a": 3, "b": 4},
]

with open("data.json", "w") as f:
    json.dump(data, f, ensure_ascii=False)

# %% [markdown]
# Условные обозначения:
# * метки звуков находятся на уровне B1;
# * метки слов находятся на уровне Y1;
# * метки синтагм находятся на уровне R2;
# * на уровне синтагм метки пауз имеют названия вида pX, где X от 1 до 6;
# * по умолчанию интонационный центр находится на последнем слове синтагмы;
# * если это не так, то перед центром стоит символ [-];
# * просодически выделеные слова отмечены знаком [+];
# * ударные гласные заканчиваются на символ 0.
