# %% [markdown]
# #### Задание на E
#
# а) Напишите функцию, которая принимает на вход целые числа M и N и возвращает список всех чисел от M до N, которые делятся на 3 и у которых первая цифра равна последней. Вызовите функцию с аргументами 100 и 10000.
#
# б) Найдите разность суммы чётных и суммы нечётных чисел из пункта (а).

# %% [markdown]
# #### Задание на A
#
# Прочитайте данные из файла rusletters.csv, который содержит список названий букв русского алфавита.
#
# а) создайте список букв, отсортированный по алфавитному порядку их названий.
#
# б) напишите функцию, которая принимает на вход слово на русском языке (состоящее из больших или маленьких букв) и возвращает кортеж, содержащий порядковые номера букв в новом алфавите. Если в слове встретились другие символы, обозначьте их числом 0.
#
# в) отсортируйте список слов из файла words.txt в новом алфавитном порядке с помощью параметра `key` функции `sorted()` и запишите его в новый текстовый файл.
