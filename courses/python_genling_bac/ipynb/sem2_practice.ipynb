# %% [markdown]
# #### Задание 1
#
# а) Постройте гистограмму распределения языков по количеству сегментов на основании таблицы Phoible.
#
# https://raw.githubusercontent.com/phoible/dev/refs/heads/master/data/phoible.csv
#
# б) Определите языковую семью языков с помощью таблицы Glottolog и постройте гистограммы для трёх самых широко представленных языковых семей.

# %% [markdown]
# #### Задание 2
#
# https://phonetics-spbu.github.io/courses/python_textbook/files/northwindsun_rus.wav
#
# https://phonetics-spbu.github.io/courses/python_textbook/files/northwindsun_rus.txt
#
# https://phonetics-spbu.github.io/courses/python_textbook/files/northwindsun_rus_ortho.txt
#
# Создайте разметку границ слов для файла northwindsun_rus.wav. Для этого:
#
# а) прочитайте файлы northwindsun_rus.txt (транскрипция) и northwindsun_rus_ortho.txt (орфография).
#
# б) создайте таблицу northwindsun_rus.csv с разделителем ; (точка с запятой), где в первой колонке поместите орфографическую запись слова, а во второй &mdash; транскрипцию. Воспользуйтесь библиотекой segments для деления на символы. Не забудьте убрать символы ударения ("\u02c8") и дуги аффрикат ("\u0361") из транскрипции и знаки пунктуации из орфографии.
#
# в) используйте сервис WebMAUS для получения файла TextGrid с границами слов.

# %% [markdown]
# #### Задание 3
#
# ---
# Если предыдущее задание вызвало у вас сложности, скачайте готовый TextGrid:
#
# https://phonetics-spbu.github.io/courses/python_textbook/files/northwindsun_rus.TextGrid
#
# ---
#
# а) Добавьте в northwindsun_rus.TextGrid новый уровень, где отметьте часть речи каждого слова. Используйте pymorphy3.
#
# б) Вырежьте все существительные и запишите в новый аудиофайл с паузами между словами по 1 с (задание со звёздочкой: сделайте так, чтобы слова шли в алфавитном порядке).
#
# в) Создайте csv-таблицу с грамматическими данными для каждого существительного.
