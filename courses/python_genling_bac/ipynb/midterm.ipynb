# %% [markdown]
# ### Коллоквиум в честь середины семестра
#
# Задания можно выполнять в любом порядке. Сдавать лучше по мере выполнения. Можно пользоваться всеми моими тетрадками и [официальной документацией](https://docs.python.org/3/).

# %% [markdown]
# #### Задание 1
#
# Напишите программу, которая принимает на вход номер автобусного билета (шесть цифр) и определяет, счастливый ли он:
#
# а) по стандартному определению (сумма первых трёх цифр равна сумме последних трёх)
#
# б) по-московски (сумма чётных цифр равна сумме нечётных)

# %% [markdown]
# #### Задание 2
#
# а) Напишите программу, которая принимает на вход слово и определяет, стоят ли его буквы в алфавитном порядке. Используйте сортировку.
#
# б) Измените программу так, чтобы она определяла, (1) стоят ли только согласные буквы слова в алфавитном порядке и (2) только гласные. Используйте list comprehension.

# %%
consonants = "бвгджзйклмнпрстфхцчшщ"
vowels = "аеёиоуыэюя"

# %% [markdown]
# #### Задание 3
#
# а) Напишите программу, которая принимает на вход два слова, и определяет, начинается ли второе на последнюю букву первого.
#
# б) Измените программу так, чтобы она принимала на вход ещё и целое число и отвечала на вопрос "начинается ли второе слово на то же буквосочетание длиной N, что и первое слово?". Например, если пользователь вводит число 3, то программа должна положительно ответить при вводе пары слов "стол" и "толк". Используйте срезы.
#
# в) (*) Измените программу так, чтобы она перебирала все сочетания длиной N в цикле и выводила на экран пересечение слов, если оно есть.

# %% [markdown]
# #### Задание 4
#
# Сверхсоставным числом называется натуральное число, у которого делителей больше, чем у любого числа, меньшего, чем оно само. Найдите все сверхсоставные числа, не превышающие 10000.
#
# <details>
# <summary>Подсказка:</summary>
#
# Сохраняйте количество делителей каждого числа в список. Потом проходите циклом по этому списку и проверяйте, больше ли количество делителей текущего числа, чем все количества делителей до него. Используйте конструкцию break/else.
# </details>

# %% [markdown]
# #### Задание 5
#
# Дан список чисел. Оцените его стандартное отклонение по формуле:
#
# $$ \sigma = \sqrt{\frac{1}{n}\sum_{i = 1}^{n}{(x_i - x_{среднее})^2}} $$
#
# Для вычисления квадратного корня возведите выражение в степень 0.5.

# %%
x = [
    86, 74, 75, 1, 35, 54, 52, 59, 46, 80, 
    85, 17, 47, 63, 48, 9, 15, 30, 84, 17,
    78, 91, 92, 96, 10, 2, 58, 40, 65, 93,
    86, 89, 12, 23, 67, 60, 65, 45, 50, 66,
    80, 93, 59, 76, 59, 48, 31, 46, 9, 79, 
]

# %% [markdown]
# #### Задание 6
#
# Найдите максимальное значение последовательности, заданной формулой:
#
# $$ a_{n} = -n^4 + 220n^3 - 15183n^2 + 321464n - 583940 $$
#
# на промежутке от 1 до 100.

# %% [markdown]
# #### Задание 7
#
# Артикуляторный темп вычисляется как количество произнесённых слогов, делённое на время, затраченное на произношение (в секундах).
#
# Дан список слов из одного высказывания, а также список пар (время начало, время конца). Определите артикуляторный темп в высказывании. Количество слогов определите как количество гласных.

# %%
words = ['в', 'июле', 'мать', 'дмитриева', 'ксения', 'фёдоровна', 'тяжело', 'заболела', 'и', 'её', 'отвезли', 'в', 'боткинскую']
times = [
    [0.0, 0.125], [0.125, 0.563], [0.563, 0.888], [0.888, 1.512], [1.512, 2.036], [2.036, 2.797], [2.876, 3.397],
    [3.397, 4.11], [4.635, 4.789], [4.789, 5.047], [5.047, 5.587], [5.587, 5.652], [5.652, 6.535]
]

vowels = "аеёиоуыэюя"

# %% [markdown]
# #### Задание 8 (*)
#
# Алиса записала сообщение для Боба на русском языке без пробелов длиной N и закодировала его следующим образом:
# 1. Записала его задом наперёд
# 2. Взяла список случайных псевдослов из русских букв длиной N
# 3. Каждую букву своего сообщения она вставила в соответствующее по порядку псевдослово следующим образом: первая буква перевёрнутого сообщения оказалась на первом месте в первом слове, вторая &mdash; на втором во втором, ..., пятая &mdash; на пятом в пятом, шестая &mdash; на первом в шестом и далее по циклу до конца. Иными словами, позиция каждой буквы в слове &mdash; это остаток от деления её позиции в перевёрнутом сообщении на 5.
#
# Помогите Бобу раскодировать сообщение!

# %%
words = ['рнклэю', 'иибёэуагщ', 'хамыьвеб', 'дкьтгрвтр', 'уяжлеи', 'вйинзя', 'гилвмпгкл', 'уьрмхгнаь', 'юцюпфлуфы']

# %% [markdown]
# #### Задание 9 (**) (для Андрея)
#
# Реализуйте алгоритм сортировки пузырьком десятью различными способами.
