# %% [markdown]
# <h1>Целочисленная арифметика</h1>

# %% [markdown]
# Операция деления (/) для целых чисел всегда возвращает значение типа float, даже если делимое делится нацело на делитель. Часто бывает необходимым выполнить деление с целочисленным результатом. Для этого в Python есть специальная операция целочисленного деления, которая обозначается //. Результатом будет число, которое было бы получено в результате деления, но с отброшенной дробной частью. Другая связанная с этим операция — это операция взятия остатка от деления, обозначаемая %.

# %%
17 / 3
# Out:
# 5.666666666666667

# %%
17 // 3
# Out:
# 5

# %%
17 % 3
# Out:
# 2

# %% [markdown]
# В случае отрицательных чисел операции по-разному определены в различных языках программирования. Например, в Python 3 округление по-прежнему будет производиться вниз. Например:

# %%
(-17) / 3
# Out:
# -5.666666666666667

# %%
(-16) // 3
# Out:
# -6

# %%
(-16) % 3
# Out:
# 2

# %% [markdown]
# Пример. Расписание уроков
# В некоторой школе расписание составлено таким образом, что на неделе 5
#  учебных дней, в которые суммарно проходит n
#  уроков. При этом количество уроков в любые два дня отличается не более чем на 1
# . Определите минимальное число уроков в день и количество дней, в которых уроков больше всего.

# %%
n = int(input())
print(n // 5)
print(n % 5)
# Out:
# 23
# 4
# 3

# %% [markdown]
# Пример. Дано трёхзначное число. Найдите сумму его цифр.

# %%
n = int(input())
d3 = n % 10
print(d3)
d2 = n // 10 % 10
print(d2)
d1 = n // 100
print(d1)
print(d1 + d2 + d3)
# Out:
# 123
# 3
# 2
# 1
# 6

# %% [markdown]
# Задача. n школьников делят между собой k
#  яблок поровну, неделящийся остаток остаётся в корзинке. Сколько яблок достанется каждому школьнику? Сколько яблок останется в корзинке?
#
# Программа получает на вход в первой строке натуральное число n
# , а во второй — целое неотрицательное число k
#  и должна вывести два целых числа: количество яблок у каждого школьника и количество яблок, оставшихся в корзинке.

# %%
# ваш код
n = int(input())
k = int(input())

print("Каждому достанется: ", k // n)
print("Останется: ", k % n)
# Out:
# 243243242423
# 23523532532532525332
# Каждому достанется:  96707856
# Останется:  71315950244

# %% [markdown]
# Задача. Дано натуральное число. Найдите число десятков в его десятичной записи (то есть предпоследнюю цифру). Если заданное число является однозначным, то необходимо вывести 0

# %%
# ваш код
n = int(input())

print(n // 10 % 10)
# Out:
# 123
# 2

# %% [markdown]
# <h1>Условный оператор if. Синтаксис условной инструкции</h1>

# %% [markdown]
# Все ранее рассматриваемые программы имели линейную структуру: все инструкции выполнялись последовательно одна за одной, каждая записанная инструкция обязательно выполнялась.
#
# Допустим, мы хотим по данному числу x
#  определить его абсолютную величину (модуль). Программа должна напечатать значение переменной x
# , если x>0
# , или же величину −x
#  в противном случае. Линейная структура программы нарушается: в зависимости от справедливости условия x>0
#  должна быть выведена одна или другая величина. Соответствующий фрагмент программы на Python имеет вид:

# %%
x = int(input())
if x > 5:
    print(x)
elif x > 10:
   print("Ноль!!")
else:
    print(-x)
# Out:
# 0
# 0

# %%
x = int(input())
if x > 0:
  print("1")
else:
  print("3")

if x < 0:
  print("2")
# Out:
# 0
# 3

# %% [markdown]
# В этой программе используется условная инструкция if («если»). После слова if указывается проверяемое условие x > 0, завершающееся двоеточием. После этого идёт блок (последовательность) инструкций, который будет выполнен, если условие истинно. В нашем примере это вывод на экран величины x. Затем идёт слово else («иначе»), также завершающееся двоеточием, и блок инструкций, который будет выполнен, если проверяемое условие неверно, то есть будет выведено значение -x.

# %% [markdown]
# Для выделения блока инструкций, относящихся к инструкции if или else, в языке Python используются отступы. Все инструкции, которые относятся к одному блоку, должны иметь равную величину отступа, то есть одинаковое число пробелов в начале строки. Рекомендуется использовать отступ в 4
#  пробела. Это одно из существенных отличий синтаксиса Python от синтаксиса большинства языков, в которых блоки выделяются специальными словами или фигурными скобками.

# %% [markdown]
# В условной инструкции может отсутствовать слово else и последующий блок. Такая инструкция называется неполным ветвлением. Например, если дано число x
#  и мы хотим заменить его на абсолютную величину x
# , то это можно сделать следующим образом:

# %%
if x < 0:
    x = -x
print(x)

# %% [markdown]
# В этом примере переменной x будет присвоено значение −x, но только в том случае, когда x < 0 . А вот инструкция print(x) будет выполнена всегда, независимо от проверяемого условия.

# %% [markdown]
# Пример: максимум из двух чисел

# %%
a = int(input())
b = int(input())
if a > b:
    m = a
else:
    m = b
print(m)
# Out:
# 1
# 1
# 1

# %% [markdown]
# Также эту задачу можно решить с помощью неполного ветвления. В этом случае нам не нужно использовать дополнительную переменную:

# %%
a = int(input())
b = int(input())
if b > a:
    a = b
print(a)
# Out:
# 1
# 5
# 5

# %% [markdown]
# Пример. Сколько разрезов нужно сделать, чтобы разрезать круглый торт на N
#  одинаковых по форме и размеру кусков?
#
# Например, для N=6
#  необходимо сделать 3
#  разреза, а для N=5
#  — 5
#  разрезов.

# %%
N = int(input())

if N % 2 == 0:
  print(N // 2)
else:
  print(N)
# Out:
# 15
# 15

# %% [markdown]
# Операции сравнения
# Как правило, в качестве проверяемого условия используется результат вычисления одной из следующих операций сравнения (или величин логического типа).
#
# < — меньше. Условие верно, если первый операнд меньше второго.
#
# \> — больше. Условие верно, если первый операнд больше второго.
#
# <= — меньше или равно. Условие верно, если первый операнд не больше второго.
#
# \>= — больше или равно. Условие верно, если первый операнд не меньше второго.
#
# == — равенство. Условие верно, если два операнда равны. Обратите внимание, что просто знак равенства для сравнения двух значений использовать нельзя, так как он означает присваивание.
#
# != — неравенство. Условие верно, если операнды не равны.

# %% [markdown]
# Пример. За день машина проезжает n
#  километров. Сколько дней нужно, чтобы проехать маршрут длиной m
#  километров?

# %%
n = int(input())
m = int(input())
if m % n == 0:
    print(m // n)
else:
    print(m // n + 1)

# %% [markdown]
# Операции сравнения возвращают значения специального логического типа bool. Выражения логического типа могут принимать одно из двух значений: True («истина») или False («ложь»).
#
# Если преобразовать логическое True к типу int, то получится 1
# , а преобразование False даст 0
# . При обратном преобразовании число 0
#  преобразуется в False, а любое ненулевое число — в True. При преобразовании str в bool пустая строка преобразуется в False, а любая непустая строка — в True.

# %% [markdown]
# Иногда нужно проверить одновременно не одно, а несколько условий. В этом помогают логические операции. В Python существуют стандартные логические операции: логическое И, логическое ИЛИ, логическое отрицание.
#
# Логическое И (конъюнкция) является бинарной операцией (то есть операцией с двумя операндами: левым и правым) и имеет вид and. Операция and возвращает True тогда и только тогда, когда оба её операнда имеют значение True.
# <br/>Логическое ИЛИ (дизъюнкция) является бинарной операцией и возвращает True тогда и только тогда, когда хотя бы один операнд равен True. Операция «логическое ИЛИ» имеет вид or.
# <br/>Логическое НЕ (отрицание) является унарной (то есть с одним операндом) операцией и имеет вид not, за которым следует единственный операнд. Логическое НЕ возвращает True, если операнд равен False, и наоборот.

# %% [markdown]
# Пример. Проверим, что число m
#  является корректным номером месяца (лежит в интервале от 1
#  до 12
# ):

# %%
if m >= 1 and m <= 12:
    print("Корректно")

# %%
if 1 <= m <= 12:
    print("Корректно")

# %%
if m == 1 or m == 2 or m == 12:
    print("Зима")

# %% [markdown]
# Задача. Дано натуральное число. Требуется определить, является ли год с данным номером високосным. Если в году 366
#  дней, он является високосным, если 365
# , то нет. Високосный год повторяется каждые четыре года, и 2024
#  год является високосным. Если год является високосным, то выведите YES, иначе выведите NO. В соответствии с григорианским календарём год является високосным, если его номер делится на 4
# , но при этом не делится на 100
# , или если он кратен 400
# .

# %%
# ваш код

# %% [markdown]
# Задача. Напишите программу, вычисляющую индекс массы тела (ИМТ) и интерпретирующую полученный результат. На вход программа принимает рост человека в сантиметрах и вес в килограммах, рассчитывает ИМТ как отношение веса в кг к квадрату роста в метрах и печатает соответствующую строку из правого столбца таблицы ниже:
# | ИМТ | Интерпретация |
# | --- | --- |
# | 16 и менее | Выраженный дефицит массы тела |
# | 16 - 18.5 | Недостаточная масса тела |
# | 18.5 - 25 | Нормальная масса тела |
# | 25 - 30 | Избыточная масса тела |
# | 30 - 35 | Ожирение 1 степени |
# | 35 - 40 | Ожирение 2 степени |
# | 40 и более | Ожирение 3 степени |

# %%
# ваш код

# %% [markdown]
# Условные инструкции могут быть вложенными.

# %% [markdown]
# Пример. Даны три целых числа. Определите, сколько среди них совпадающих. Программа должна вывести одно из чисел: 3
#  (если все числа совпадают), 2
#  (если два совпадает) или 0
#  (если все числа различны).

# %%
a = int(input())
b = int(input())
c = int(input())
n=0
if a==b:
  if b==c:
    n=3
  else:
    n=2
else:
  if b==c:
    n=2
  if a==c:
    n=2

print(n)

# %% [markdown]
# Задача. Даны три числа - длины сторон треугольника. Определите и выведите на экран, является ли треугольник равносторонним, равнобедренным или разносторонним.

# %%
# ваш код

# %% [markdown]
# Задача. Бизнесмен Василий после прочтения известной книги решил открыть новый бизнес — отгружать апельсины бочками. Партнёрам важно знать, сколько именно бочек апельсинов отгружается каждый день.
#
# Мобильный телефон Василия поддерживает только транслит, поэтому он передаёт сообщения вида «n
#  bochek». Например, «3
#  bochki» или «1
#  bochka».

# %%
# ваш код
