# %% [markdown]
# <h2>Дополнительные задачи (строки)</h2>

# %% [markdown]
# Задача 1. Напишите программу, которая принимает строку и возвращает количество гласных букв в ней. (Язык можете выбрать любой, с алфавитной письменностью)

# %% [markdown]
# Задача 2. Напишите программу, которая принимает на вход строку с 11 цифрами, начинающуюся на 8 (например, 81234567890), а возвращает ее в формате "+7 (123) 456-78-90"

# %% [markdown]
# Задача 3. Напишите программу, которая проверяет, является ли строка валидным e-mail адресом:
# 1. содержит @
# 2. после @ есть хотя бы одна точка
# 3. Домен длиной не меньше 2 (то, что идет после последней точки, например, com или ru)
# 4. Не содержит пробелов

# %% [markdown]
# Задача 4. Напишите программу, которая принимает на вход строку с числами и находит в ней "счастливые" (те, у которых сумма цифр четная). Например, на строку "123 456 789 100" программа должна вернуть список [123, 789]

# %% [markdown]
# Задача 5. Напишите программу, которая строку в snake_case переводит в строку в camelCase. Например, what-a-year-this-week-had-been будет переведена в whatAYearThisWeekHadBeen

# %% [markdown]
# Задача 6. Напишите программу, которая переведет строку из camelCase в kebab-case. Например, whatAYearThisWeekHadBeen будет переведена в what-a-year-this-week-had-been.
