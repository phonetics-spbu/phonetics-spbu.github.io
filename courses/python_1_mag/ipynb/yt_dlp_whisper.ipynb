# %% [markdown]
# <h2>Как скачать видео без впн и регистрации (и смс)</h2>

# %% [markdown]
# Подключимся через colab к своему Google Drive:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Теперь нужно установить в колаб библиотеку yt-dlp:

# %%
# !pip install yt-dlp
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.3/182.3 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 51.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# Скачать видео себе на Google Drive можно следующей командой:

# %%
# !yt-dlp -P "/content/drive/MyDrive" "https://www.youtube.com/shorts/9AjIYRoW7W8"

# %% [markdown]
# Здесь в первых кавычках указывается путь к вашему каталогу, во вторых - ссылка на видео

# %% [markdown]
# Можно вместо видео скачать только аудио:

# %%
# !yt-dlp -x --audio-format mp3 "https://www.youtube.com/shorts/9AjIYRoW7W8"

# %% [markdown]
# Чтобы узнать в каких форматах представлено видео, выполните следующую команду:

# %%
# !yt-dlp -F "https://www.youtube.com/shorts/9AjIYRoW7W8"
# Out:
# [youtube] Extracting URL: https://www.youtube.com/shorts/9AjIYRoW7W8
# [youtube] 9AjIYRoW7W8: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] 9AjIYRoW7W8: Downloading android vr player API JSON
# [info] Available formats for 9AjIYRoW7W8:
# ID  EXT   RESOLUTION FPS CH │   FILESIZE   TBR PROTO │ VCODEC          VBR ACODEC      ABR ASR MORE INFO
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# sb2 mhtml 25x45        1    │                  mhtml │ images                                  storyboard
# ...

# %% [markdown]
# Чтобы скачать видео в нужном вам формате, воспользуйтесь командой ниже. Число в команде - это id формата из таблицы выше.

# %%
# !yt-dlp -f 18 --merge-output-format mp4 -P "/content/drive/MyDrive" "https://www.youtube.com/shorts/9AjIYRoW7W8"
# Out:
# [youtube] Extracting URL: https://www.youtube.com/shorts/9AjIYRoW7W8
# [youtube] 9AjIYRoW7W8: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] 9AjIYRoW7W8: Downloading android vr player API JSON
# [info] 9AjIYRoW7W8: Downloading 1 format(s): 18
# [download] Destination: /content/drive/MyDrive/The FUNNIEST Cat Videos! [9AjIYRoW7W8].mp4
# [download] 100% of    4.22MiB in 00:00:00 at 18.71MiB/s

# %% [markdown]
# Также, видео можно сохранить под новым именем:

# %%
# !yt-dlp -o "my_video" -P "/content/drive/MyDrive" "https://www.youtube.com/shorts/9AjIYRoW7W8"
# Out:
# [youtube] Extracting URL: https://www.youtube.com/shorts/9AjIYRoW7W8
# [youtube] 9AjIYRoW7W8: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] 9AjIYRoW7W8: Downloading android vr player API JSON
# [info] 9AjIYRoW7W8: Downloading 1 format(s): 399+251
# [download] Destination: /content/drive/MyDrive/my_video.mp4.f399.mp4
# [download] 100% of   10.75MiB in 00:00:00 at 49.18MiB/s
# [download] Destination: /content/drive/MyDrive/my_video.mp4.f251.webm
# [download] 100% of  927.59KiB in 00:00:00 at 10.72MiB/s
# [Merger] Merging formats into "/content/drive/MyDrive/my_video.mp4.webm"
# ...

# %% [markdown]
# <h2>Как расшифровать аудио с помощью Whisper AI</h2>

# %% [markdown]
# Для начала скачаем аудио для расшифровки:

# %%
# !wget https://phonetics-spbu.github.io/courses/python_1_mag/files/narrative1.wav

# %%
# установка библиотек
# !pip install -U openai-whisper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 kB 20.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.5/201.5 MB 6.0 MB/s eta 0:00:00
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20250625-py3-none-any.whl size=803979 sha256=e57b4e40f29d4bfb94fb1676ad7aa5604fe8c2caeca0bbe297575b57996a2e75
#   Stored in directory: /root/.cache/pip/wheels/61/d2/20/09ec9bef734d126cba375b15898010b6cc28578d8afdde5869
# Successfully built openai-whisper
# ...

# %%
import whisper

# %% [markdown]
# Чтобы прослушать аудио прямо в колабе, можно использовать библиотеку IPython.display:

# %%
from IPython.display import Audio

# воспроизведем аудио
Audio('narrative1.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Чтобы распознать аудио, нужно выбрать размер модели (tiny, base, small, medium, large, turbo) и скачать её:

# %%
model = whisper.load_model("medium")
# Out:
# 100%|██████████████████████████████████████| 1.42G/1.42G [00:09<00:00, 157MiB/s]

# %% [markdown]
# Также существуют модели tiny.en, base.en, small.en, medium.en, оптимизированные для английского языка

# %% [markdown]
# Теперь можно расшифровать аудио:

# %%
result = model.transcribe("narrative1.wav")
print(result['text'])
# Out:
# /usr/local/lib/python3.12/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  ο Βοριάς και ο Ήλιος μάλλονταν για το ποιος από τους δύο είναι ο δυνατότερος, όταν έτυχε να περάσει από μπροστά τους ένας ταξιδιώτης που φορούσε κάπα. Όταν τον είδαν, ο Βοριάς και ο Ήλιος συμφώνησαν ότι όποιος από τους δύο έκανε τον ταξιδιώτη να βγάλει την κάπα του θα θεωρούνταν ο πιο δυνατός. Ο Βοριάς άρχισε τότε να φυσάει με μανία, αλλά όσο περισσότερο φυσούσε, τόσο περισσότερο ότι λιγόταν με την κάπα το ταξιδιώτης, ως που ο Βοριάς κουράστηκε και σταμάτησε να φυσάει. Τότε ο Ήλιος άρχισε με τη σειρά του να λάμπει δυνατά και γρήγορα ο ταξιδιώτης ζεστάθηκε και έβγαλε την κάπα του. Έτσι ο Βοριάς αναγκάστηκε να παραδεχτεί ότι ο Ήλιος είναι πιο δυνατός από αυτόν.

# %% [markdown]
# Можем напечатать текст в файл:

# %%
with open('result.txt', 'w', encoding="UTF-8") as f:
  f.write(result['text'])

# %%
# что ещё есть в 'result'
from pprint import pprint
pprint(result)
# Out:
# {'language': 'el',
#  'segments': [{'avg_logprob': -0.09433881123860677,
#                'compression_ratio': 2.393081761006289,
#                'end': 3.6,
#                'id': 0,
#                'no_speech_prob': 0.16413447260856628,
#                'seek': 0,
#                'start': 0.0,
#                'temperature': 0.0,
#                'text': ' ο Βοριάς και ο Ήλιος μάλλονταν για το ποιος από τους '
#                        'δύο είναι ο δυνατότερος,',
#                'tokens': [50364,
#                           11383,
#                           1158,
#                           240,
#                           1800,
#                           13477,
#                           3849,
#                           3371,
#                           8839,
#                           11383,
#                           1158,
#                           231,
#                           48253,
#                           22281,
#                           5337,
# ...

# %% [markdown]
# Whisper умеет переводить...

# %%
result = model.transcribe("narrative1.wav",
                          task="translate")
print(result['text'])
# Out:
# /usr/local/lib/python3.12/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  Vourias and Ilios were arguing about who was the strongest of the two. When they happened to pass in front of them a traveller in a hat. When they saw him, Vourias and Ilios agreed that whoever of the two made the traveller take off his hat would be considered the strongest. Vourias then began to cough with mania, but the more he coughed, the more his travel was reduced to a hat, until Vourias got tired and stopped coughing. Then Ilios began to shine brightly in his turn, and soon the traveller warmed up and took off his hat. Thus, Vourias was forced to accept that Ilios was stronger than him.

# %% [markdown]
# Можно определить язык

# %%
# загружаем базовую модель
model = whisper.load_model("base")

# загружаем аудио
audio = whisper.load_audio("narrative1.wav")

# извлекаем первые 30 секунд аудио (если аудио меньше, то добиваем нулями)
audio = whisper.pad_or_trim(audio)

# получаем log-Mel спектрограмму и передаем её на то же устройство, где находится модель
mel = whisper.log_mel_spectrogram(audio).to(model.device)

# получаем словарь уверенностей распознанного языка
_, probs = model.detect_language(mel)
print(f"Распознанный язык: {max(probs, key=probs.get)}")

# выполняем распознавание речи
options = whisper.DecodingOptions()
result = whisper.decode(model, mel, options)

# выводим полученный текст
print(result.text)
# Out:
# Распознанный язык: el
# Ο βοριασκοίοιος μάλλοναν για το πιο σαπλουσδύο είναι ο δυνατότερος. Όταν έτυχε να περάσει από προστά τους ένας ταξιδιότις που φορούσε κάπα. Όταν τον ίδαν, ο βοριασκοίοιος συμφώνησαν ότι όποιος από τους δύο έκανε το δοξιδιότι να βγάλει την κάπα του θα θεωρούνταν ο πιο δυνατός. Ο βοριασκοί τότε να φυσάει με μανία, αλλά στο περισσότερο φυσούσε, τόσο περισσότερο τυλυγόταν με την κάπα του ταξιδιότις, ως ο βορ

# %%
probs
# Out:
# {'zh': 6.659400355601974e-07,
#  'ka': 6.676872033040127e-08,
#  'bo': 7.75220954096767e-08,
#  'ta': 3.858748129914602e-07,
#  'as': 3.1493310181929246e-09,
#  'ne': 9.753185992167346e-08,
#  'eu': 1.0024090443039313e-05,
#  'lt': 1.7294804877110437e-07,
#  'da': 9.317403737441055e-07,
#  'te': 4.008141445410729e-07,
#  'tg': 6.991095258257474e-09,
#  'ha': 4.458351188230125e-10,
#  'vi': 4.036363861814607e-06,
#  'lv': 3.3746141525625717e-07,
#  'es': 0.00013583790860138834,
#  'tk': 3.082813171406684e-10,
#  'fo': 4.3336396515769593e-07,
#  'so': 1.2020965556303054e-08,
#  'ro': 2.3103082185116364e-06,
#  'nn': 3.240939986426383e-05,
#  'ms': 6.308530373644317e-07,
#  'mi': 8.515355176541561e-08,
#  'az': 4.818240313397837e-07,
#  'en': 3.0090361178736202e-05,
#  'lo': 3.407969373370179e-08,
#  'tl': 4.942896339343861e-06,
#  'kn': 4.337569592394175e-08,
#  'th': 5.5849639579719224e-08,
#  'id': 2.24031259676849e-06,
#  'ca': 2.5171941615553806e-06,
# ...

# %% [markdown]
# Задание. Напишите функцию, которая обрабатывает аудио-файл - расшифровывает его с помощью Whisper и записывает в json список словарей, каждый из которых содержит текст токена, соответствующие ему время начала и конца. Аргументы функции - путь к аудио-файлу и размер модели Whisper. Имя json должно быть таким же, как имя аудио.
