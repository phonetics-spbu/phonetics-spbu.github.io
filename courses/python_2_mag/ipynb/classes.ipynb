# %% [markdown]
# <h2>Классы в Python</h2>
#
# <p> Классы - это фундаментальная концепция объектно-ориентированного программирования (ООП). Они позволяют создавать собственные типы данных.</p>
#
# <p>Класс - это шаблон для создания объектов. Объекты - это экземпляры классов.</p>
#
# <p>
# Классы в Python предоставляют мощный инструмент для организации кода, делая его более:
#
# * Модульным - легче поддерживать и изменять
#
# * Переиспользуемым - код можно использовать многократно
#
# * Расширяемым - легко добавлять новую функциональность
#
# * Понятным - лучше отражает реальные объекты и процессы</p>

# %%
class Dog:
    # Атрибут класса (общий для всех экземпляров)
    species = "Canis familiaris"

    # Конструктор (инициализатор)
    def __init__(self, name, age):
        # Атрибуты экземпляра
        self.name = name
        self.age = age

    # Метод экземпляра
    def bark(self):
        return f"{self.name} говорит: Гав!"

    # Еще один метод
    def get_info(self):
        return f"{self.name} - {self.age} лет, вид: {self.species}"

# %%
# Создание объектов (экземпляров класса)
dog1 = Dog("Бобик", 3)
dog2 = Dog("Шарик", 5)

dog1.name
# Out:
# 'Бобик'

# %%
# Использование методов
print(dog1.bark())  # Бобик говорит: Гав!
print(dog2.get_info())  # Шарик - 5 лет, вид: Canis familiaris
# Out:
# Бобик говорит: Гав!
# Шарик - 5 лет, вид: Canis familiaris

# %%
# Доступ к атрибутам
print(dog1.name)  # Бобик
print(dog2.age)   # 5
# Out:
# Бобик
# 5

# %% [markdown]
# <h3>Ключевые понятия ООП</h3>
# <h4>1. Инкапсуляция</h4>

# %%
class BankAccount:
    def __init__(self, owner, balance=0):
        self.owner = owner
        self.__balance = balance  # Приватный атрибут

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            return f"Пополнено: {amount}. Баланс: {self.__balance}"
        return "Неверная сумма"

    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            return f"Снято: {amount}. Баланс: {self.__balance}"
        return "Недостаточно средств"

    def get_balance(self):
        return self.__balance

# %%
# Использование
account = BankAccount("Иван Иванов", 1000)
print(account.deposit(500))  # Пополнено: 500. Баланс: 1500
print(account.withdraw(200)) # Снято: 200. Баланс: 1300
account.get_balance()
# Out:
# Пополнено: 500. Баланс: 1500
# Снято: 200. Баланс: 1300
# 1300

# %%
account.balance
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3104/600214497.py in <cell line: 0>()
# ----> 1 account.balance
#
# AttributeError: 'BankAccount' object has no attribute 'balance'

# %% [markdown]
# <h4>2. Наследование</h4>

# %%
# Базовый класс
class Animal:
    def __init__(self, name):
        self.name = name

    def speak(self):
        raise NotImplementedError("Должен быть реализован в подклассе")

# Подкласс
class Cat(Animal):
    def speak(self):
        return f"{self.name} говорит: Мяу!"

# Другой подкласс
class Dog(Animal):
    def speak(self):
        return f"{self.name} говорит: Гав!"

    def fetch(self):
        return f"{self.name} принес палку!"

# %%
# Использование
animals = [Cat("Мурка"), Dog("Бобик")]

for animal in animals:
    print(animal.speak())
# Out:
# Мурка говорит: Мяу!
# Бобик говорит: Гав!

# %% [markdown]
# <h4>3. Полиморфизм</h4>

# %%
class Rectangle:
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

class Circle:
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius ** 2

# %%
# Разные классы, но одинаковый метод
shapes = [Rectangle(5, 10), Circle(7)]

for shape in shapes:
    print(f"Площадь: {shape.area()}")
# Out:
# Площадь: 50
# Площадь: 153.86

# %% [markdown]
# <h4>Специальные методы</h4>

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __str__(self):
        return f"Vector    ({self.x}, {self.y})"

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __mul__(self, scalar):
        return Vector(self.x * scalar, self.y * scalar)

# %%
# Использование
v1 = Vector(2, 3)
v2 = Vector(1, 4)

print(v1)           # Vector(2, 3)
print(v1 + v2)      # Vector(3, 7)
print(v1 * 3)       # Vector(6, 9)
# Out:
# Vector    (2, 3)
# Vector    (3, 7)
# Vector    (6, 9)

# %% [markdown]
# Еще пример использования:

# %%
class Student:
    def __init__(self, name, student_id):
        self.name = name
        self.student_id = student_id
        self.grades = []

    def add_grade(self, grade):
        if 0 <= grade <= 100:
            self.grades.append(grade)
        else:
            print("Оценка должна быть от 0 до 100")

    def average_grade(self):
        if not self.grades:
            return 0
        return sum(self.grades) / len(self.grades)

    def __str__(self):
        return f"Студент: {self.name} (ID: {self.student_id}), Средний балл: {self.average_grade():.2f}"

class Course:
    def __init__(self, name):
        self.name = name
        self.students = []

    def add_student(self, student):
        self.students.append(student)

    def get_top_student(self):
        if not self.students:
            return None
        return max(self.students, key=lambda s: s.average_grade())

# %%
# Использование
course = Course("Программирование на Python")

student1 = Student("Алексей", "001")
student1.add_grade(95)
student1.add_grade(88)

student2 = Student("Мария", "002")
student2.add_grade(92)
student2.add_grade(96)

course.add_student(student1)
course.add_student(student2)

for student in course.students:
    print(student)

top_student = course.get_top_student()
print(f"\nЛучший студент: {top_student.name}")
# Out:
# Студент: Алексей (ID: 001), Средний балл: 91.50
# Студент: Мария (ID: 002), Средний балл: 94.00
#
# Лучший студент: Мария

# %% [markdown]
# **Задание**: библиотека
#
# Создайте класс Book с атрибутами: title, author, is_available
#
# Создайте класс Library: список книг
#
# Методы: add_book(), borrow_book(title), return_book(title), show_available_books()

# %%
class Book:
  def __init__(self, title, author, is_available):
    self.title = title
    self.author = author
    self.is_available = is_available

  def change_availability(self):
    self.is_available = not self.is_available

  def __str__(self):
    return f"{self.author}. {self.title}. {"Книга доступна" if self.is_available else "Книга недоступна"}"

# %%
class Library:
  def __init__(self):
    self.book_list = []

  def add_book(self, new_book):
    self.book_list.append(new_book)

  def show_library_books(self):
    for i, book in enumerate(self.book_list):
      print(f"{i + 1}. {book}")

  def borrow_book(self, title):
    book_exists = False
    for book in self.book_list:
      if book.title == title:
        book_exists = True
        if book.is_available:
          book.change_availability()
          print(f"Книга {book.title} доступна к выдаче")
        else:
          print(f"Книга {book.title} недоступна к выдаче")
    if not book_exists:
      print("Такой книги нет в библиотеке")

  def return_book(self, title):
    book_exists = False
    for book in self.book_list:
      if book.title == title:
        book_exists = True
        if not book.is_available:
          book.change_availability()
          print(f"Книгу {book.title} вернули")
    if not book_exists:
      new_book = Book(title, "", True)
      self.book_list.append(new_book)
      print(f"Книга {title} добавлена в библиотеку")

  def show_available_books(self):
    i = 1
    for book in self.book_list:
      if book.is_available:
        print(f"{i}. {book}")
        i = i + 1

# %%
book1 = Book("Древнегреческий язык", "Козаржевский", True)
book2 = Book("Преступление и наказание", "Достоевский", True)

library = Library()
library.add_book(book1)
library.add_book(book2)

library.borrow_book("Преступление и наказание")
library.show_available_books()

library.return_book("Преступление и наказание")
library.show_available_books()

library.return_book("Древнегреческая мифология")
library.show_available_books()

library.borrow_book("Древнегреческий язык")
library.show_library_books()
# Out:
# Книга Преступление и наказание доступна к выдаче
# 1. Козаржевский. Древнегреческий язык. Книга доступна
# Книгу Преступление и наказание вернули
# 1. Козаржевский. Древнегреческий язык. Книга доступна
# 2. Достоевский. Преступление и наказание. Книга доступна
# Книга Древнегреческая мифология добавлена в библиотеку
# 1. Козаржевский. Древнегреческий язык. Книга доступна
# 2. Достоевский. Преступление и наказание. Книга доступна
# 3. . Древнегреческая мифология. Книга доступна
# Книга Древнегреческий язык доступна к выдаче
# 1. Козаржевский. Древнегреческий язык. Книга недоступна
# 2. Достоевский. Преступление и наказание. Книга доступна
# 3. . Древнегреческая мифология. Книга доступна
